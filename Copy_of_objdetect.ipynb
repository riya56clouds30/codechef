# %% [markdown]
# <a href="https://colab.research.google.com/github/riya56clouds30/codechef/blob/main/Copy_of_objdetect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python

# %%
pip install matplotlib

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 905.3/905.3 kB 13.8 MB/s eta 0:00:00
# ...

# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

# %%
model =YOLO('yolov5s.pt')
# Out:
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.

# %%
import cv2
import matplotlib.pyplot as plt
image_path= 'bts.jpg'
image =cv2.imread(image_path)
image_rgb = cv2.cvtColor(image ,cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
from ultralytics import YOLO
model = YOLO('yolov5s.pt')
# Out:
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.

# %%
results = model.predict(source = 'bts.jpg', save= True)
for result in results:
  result.show()
# Out:
# image 1/1 /content/bts.jpg: 640x448 9 persons, 653.5ms
# Speed: 16.7ms preprocess, 653.5ms inference, 38.4ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to runs/detect/predict
# <PIL.Image.Image image mode=RGB size=474x711>
